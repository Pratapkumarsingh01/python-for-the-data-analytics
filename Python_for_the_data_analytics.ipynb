# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratapkumarsingh01/python-for-the-data-analytics/blob/main/Python_for_the_data_analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
2+2
# Out:
# 4

# %%
print (2+2)
print (3*3)
# Out:
# 4
# 9

# %%
# this is the comment written by pratap

# %%
#this is the comment
2+2 #another comment
# Out:
# 4

# %%
a=2
b=12
a+b
# Out:
# 14
